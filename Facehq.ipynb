# %% [markdown]
# <a href="https://colab.research.google.com/github/Manan1811/FaceNet-Model/blob/facehq_creation/Facehq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Manan1811/outlier-experiment.git -b facehq_creation
# Out:
# Cloning into 'outlier-experiment'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11720 (delta 2), reused 7 (delta 2), pack-reused 11710
# Receiving objects: 100% (11720/11720), 66.43 MiB | 39.95 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f276f4b0-105b-42e6-9ef4-f4d27544d0c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f276f4b0-105b-42e6-9ef4-f4d27544d0c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mananagrawal1811","key":"a80a5574270ff89c6bb7e6087401dcc4"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
cd outlier-experiment
# Out:
# /content/outlier-experiment

# %%
# !wget https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/static/imdb_crop.tar
# Out:
# --2020-10-19 17:34:23--  https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/static/imdb_crop.tar
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.162
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7012157440 (6.5G) [application/x-tar]
# Saving to: ‘imdb_crop.tar’
#
# imdb_crop.tar       100%[===================>]   6.53G  16.7MB/s    in 6m 5s
#
# 2020-10-19 17:40:29 (18.3 MB/s) - ‘imdb_crop.tar’ saved [7012157440/7012157440]

# %%
# !tar -xf imdb_crop.tar

# %%
# !mkdir ffhq

# %%
! bash import_weights.sh
# Out:
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2020-10-19 18:01:39--  https://docs.google.com/uc?export=download&id=1PZ_6Zsy1Vb0s0JmjEmVd8FS99zoMCiN1
# Resolving docs.google.com (docs.google.com)... 74.125.195.139, 74.125.195.101, 74.125.195.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.195.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-4s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/255u00hkhdvh2hlt00lqj0qsbl8rl7p6/1603130475000/09379222848295305915/*/1PZ_6Zsy1Vb0s0JmjEmVd8FS99zoMCiN1?e=download [following]
# ...
# --2020-10-19 18:01:40--  https://doc-04-4s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/255u00hkhdvh2hlt00lqj0qsbl8rl7p6/1603130475000/09379222848295305915/*/1PZ_6Zsy1Vb0s0JmjEmVd8FS99zoMCiN1?e=download
# ...

# %%
# !python age_train.py
# Out:
# 2020-10-19 18:02:00.357074: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-19 18:02:12.006955: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-19 18:02:12.039200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-19 18:02:12.039792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-19 18:02:12.039856: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
! rm -rf imdb_crop

# %%
# !kaggle datasets download -d arnaud58/flickrfaceshq-dataset-ffhq
# Out:
# ...
# 100% 19.5G/19.5G [08:10<00:00, 19.9MB/s]
# 100% 19.5G/19.5G [08:10<00:00, 42.6MB/s]

# %%
! unzip flickrfaceshq-dataset-ffhq.zip -d ffhq
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ffhq/45451.png
#   inflating: ffhq/45452.png
#   inflating: ffhq/45453.png
#   inflating: ffhq/45454.png
#   inflating: ffhq/45455.png
#   inflating: ffhq/45456.png
#   inflating: ffhq/45457.png
#   inflating: ffhq/45458.png
#   inflating: ffhq/45459.png
#   inflating: ffhq/45460.png
#   inflating: ffhq/45461.png
#   inflating: ffhq/45462.png
#   inflating: ffhq/45463.png
#   inflating: ffhq/45464.png
#   inflating: ffhq/45465.png
#   inflating: ffhq/45466.png
#   inflating: ffhq/45467.png
#   inflating: ffhq/45468.png
#   inflating: ffhq/45469.png
#   inflating: ffhq/45470.png
#   inflating: ffhq/45471.png
#   inflating: ffhq/45472.png
#   inflating: ffhq/45473.png
#   inflating: ffhq/45474.png
#   inflating: ffhq/45475.png
#   inflating: ffhq/45476.png
#   inflating: ffhq/45477.png
#   inflating: ffhq/45478.png
#   inflating: ffhq/45479.png
#   inflating: ffhq/45480.png
#   inflating: ffhq/45481.png
# ...

# %%
! du -h Model_checkpoint
# Out:
# 4.0K	Model_checkpoint/assets
# 160K	Model_checkpoint/variables
# 512K	Model_checkpoint

# %%
! du -h ../outlier-experiment
# Out:
# 4.0K	../outlier-experiment/.ipynb_checkpoints
# 672K	../outlier-experiment/slim_dataset/Test_dataset/testA
# 688K	../outlier-experiment/slim_dataset/Test_dataset/testB
# 1.4M	../outlier-experiment/slim_dataset/Test_dataset
# 14M	../outlier-experiment/slim_dataset/Train_dataset/trainA
# 7.7M	../outlier-experiment/slim_dataset/Train_dataset/trainB
# 22M	../outlier-experiment/slim_dataset/Train_dataset
# 23M	../outlier-experiment/slim_dataset
# 12K	../outlier-experiment/models/__pycache__
# 28K	../outlier-experiment/models
# 177M	../outlier-experiment/Facenet
# 75M	../outlier-experiment/crop_part1
# 19G	../outlier-experiment/ffhq
# 8.0K	../outlier-experiment/.git/logs/refs/remotes/origin
# 12K	../outlier-experiment/.git/logs/refs/remotes
# 8.0K	../outlier-experiment/.git/logs/refs/heads
# 24K	../outlier-experiment/.git/logs/refs
# 32K	../outlier-experiment/.git/logs
# 8.0K	../outlier-experiment/.git/info
# 4.0K	../outlier-experiment/.git/objects/info
# ...

# %%
! ls -sh flickrfaceshq-dataset-ffhq.zip
# Out:
# 20G flickrfaceshq-dataset-ffhq.zip

# %%
import os 
print(len(os.listdir('ffhq')))
# Out:
# 48447

# %%
# !python create_facehq.py --img_dir ffhq
# Out:
# 2020-10-19 20:29:32.407895: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-19 20:29:36.629705: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-19 20:29:36.683447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-19 20:29:36.684119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-19 20:29:36.684170: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv Model_checkpoint/ '/content/drive/My Drive/'
